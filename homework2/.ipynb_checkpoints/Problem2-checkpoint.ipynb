# %%
import os
import shutil
import itertools
from glob import glob
import random
from collections import Counter
import numpy as np
import pandas as pd
import tensorflow as tf

import keras
from keras import layers
from keras import models
from keras.optimizers import Adam
from keras.preprocessing import image

from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical
from keras.utils import plot_model
from keras import backend as K

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.preprocessing import label_binarize
from sklearn.utils.multiclass import unique_labels
from sklearn.utils import class_weight
from sklearn.model_selection import KFold
from scipy import interp
from itertools import cycle

from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout, AveragePooling2D
model = models.Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128,128,3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', ))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', ))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', ))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dropout(.50))
model.add(Dense(512, activation='relu',))
model.add(Dense(5, activation='softmax'))

# %%
train_ds_bal = keras.utils.image_dataset_from_directory(
    "./Images_Used/training", 
    batch_size=32, 
    image_size=(128, 128),
    shuffle=True,
    label_mode="categorical"
)

val_data = keras.utils.image_dataset_from_directory(
    './Images_Used/validation',
    image_size=(128, 128), 
    batch_size=32,
    shuffle=True,
    label_mode="categorical"
)

test_ds = keras.utils.image_dataset_from_directory(
    './Images_Used/testing',
    image_size=(128, 128), 
    batch_size=32,
    shuffle=True,
    label_mode="categorical"
)

print(model.summary())
opt = Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# Found 567 files belonging to 5 classes.
# Found 161 files belonging to 5 classes.
# Found 84 files belonging to 5 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 126, 126, 32)      896
#
#  max_pooling2d_8 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 14, 14, 128)      0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 128)       147584
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  dropout_2 (Dropout)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 512)               2359808
#
#  dense_5 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 2,603,205
# Trainable params: 2,603,205
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(train_ds_bal, batch_size=32, epochs=50, validation_data=val_data)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 5s 267ms/step - loss: 14.2433 - accuracy: 0.1887 - val_loss: 1.6162 - val_accuracy: 0.2112
# Epoch 2/50
# 18/18 [==============================] - 5s 266ms/step - loss: 1.6143 - accuracy: 0.2257 - val_loss: 1.5982 - val_accuracy: 0.2360
# Epoch 3/50
# 18/18 [==============================] - 5s 268ms/step - loss: 1.6046 - accuracy: 0.2381 - val_loss: 1.6023 - val_accuracy: 0.2609
# Epoch 4/50
# 18/18 [==============================] - 5s 269ms/step - loss: 1.5939 - accuracy: 0.2646 - val_loss: 1.5896 - val_accuracy: 0.2671
# Epoch 5/50
# 18/18 [==============================] - 5s 294ms/step - loss: 1.5947 - accuracy: 0.2628 - val_loss: 1.6109 - val_accuracy: 0.2298
# Epoch 6/50
# 18/18 [==============================] - 5s 288ms/step - loss: 1.5864 - accuracy: 0.2787 - val_loss: 1.5874 - val_accuracy: 0.2174
# Epoch 7/50
# 18/18 [==============================] - 5s 276ms/step - loss: 1.5777 - accuracy: 0.2575 - val_loss: 1.6208 - val_accuracy: 0.2112
# Epoch 8/50
# 18/18 [==============================] - 6s 326ms/step - loss: 1.5964 - accuracy: 0.2381 - val_loss: 1.6113 - val_accuracy: 0.2422
# Epoch 9/50
# 18/18 [==============================] - 6s 347ms/step - loss: 1.5780 - accuracy: 0.2769 - val_loss: 1.6744 - val_accuracy: 0.2112
# Epoch 10/50
# 18/18 [==============================] - 5s 306ms/step - loss: 1.5694 - accuracy: 0.2981 - val_loss: 1.6540 - val_accuracy: 0.2360
# Epoch 11/50
# 18/18 [==============================] - 6s 331ms/step - loss: 1.5271 - accuracy: 0.2963 - val_loss: 1.7543 - val_accuracy: 0.2298
# Epoch 12/50
# 18/18 [==============================] - 6s 324ms/step - loss: 1.5220 - accuracy: 0.2875 - val_loss: 1.6182 - val_accuracy: 0.2733
# Epoch 13/50
# 18/18 [==============================] - 5s 302ms/step - loss: 1.5141 - accuracy: 0.3069 - val_loss: 1.6314 - val_accuracy: 0.2484
# Epoch 35/50
# 18/18 [==============================] - 5s 302ms/step - loss: 1.0056 - accuracy: 0.5697 - val_loss: 2.0332 - val_accuracy: 0.3043
# Epoch 36/50
# 18/18 [==============================] - 5s 302ms/step - loss: 1.0444 - accuracy: 0.5644 - val_loss: 1.9750 - val_accuracy: 0.2981
# Epoch 37/50
# 18/18 [==============================] - 6s 323ms/step - loss: 0.9704 - accuracy: 0.5979 - val_loss: 2.3426 - val_accuracy: 0.2733
# Epoch 38/50
# 18/18 [==============================] - 5s 262ms/step - loss: 0.9656 - accuracy: 0.6067 - val_loss: 2.0334 - val_accuracy: 0.2857
# Epoch 39/50
# 18/18 [==============================] - 6s 302ms/step - loss: 0.9463 - accuracy: 0.5838 - val_loss: 2.3046 - val_accuracy: 0.2671
# Epoch 40/50
# 18/18 [==============================] - 6s 312ms/step - loss: 0.8718 - accuracy: 0.6173 - val_loss: 2.3093 - val_accuracy: 0.2981
# Epoch 41/50
# 18/18 [==============================] - 5s 285ms/step - loss: 0.8329 - accuracy: 0.6508 - val_loss: 2.3555 - val_accuracy: 0.3106
# Epoch 42/50
# 18/18 [==============================] - 7s 380ms/step - loss: 0.8830 - accuracy: 0.6526 - val_loss: 2.1839 - val_accuracy: 0.2919
# Epoch 43/50
# 18/18 [==============================] - 7s 385ms/step - loss: 0.8720 - accuracy: 0.6578 - val_loss: 2.3295 - val_accuracy: 0.2795
# Epoch 44/50
# 18/18 [==============================] - 7s 381ms/step - loss: 0.9567 - accuracy: 0.6208 - val_loss: 2.3730 - val_accuracy: 0.2547
# Epoch 45/50
# 18/18 [==============================] - 7s 370ms/step - loss: 0.8271 - accuracy: 0.6473 - val_loss: 2.9093 - val_accuracy: 0.2919
# Epoch 46/50
# 18/18 [==============================] - 7s 361ms/step - loss: 0.8471 - accuracy: 0.6631 - val_loss: 2.9782 - val_accuracy: 0.2733
# Epoch 47/50
# 18/18 [==============================] - 6s 335ms/step - loss: 0.7889 - accuracy: 0.6896 - val_loss: 2.5633 - val_accuracy: 0.2981
# Epoch 48/50
# 18/18 [==============================] - 6s 347ms/step - loss: 0.7770 - accuracy: 0.6914 - val_loss: 2.6338 - val_accuracy: 0.2795
# Epoch 49/50
# 18/18 [==============================] - 5s 300ms/step - loss: 0.7605 - accuracy: 0.6966 - val_loss: 2.8341 - val_accuracy: 0.2795
# Epoch 50/50
# 18/18 [==============================] - 6s 346ms/step - loss: 0.7016 - accuracy: 0.7337 - val_loss: 2.7590 - val_accuracy: 0.3043

# %%
x_data = []
y_data = []

for x, y in test_ds:
    x_data.append(x)
    y_data.append(y)

x_data = tf.concat(x_data, axis=0)
y_data = tf.concat(y_data, axis=0)

probs = model.predict(x_data)

y_data_indices = tf.argmax(y_data, axis=1)
probs_indices = tf.argmax(probs, axis=1)
# Out:
# 3/3 [==============================] - 0s 69ms/step

# %%
con_matrix = confusion_matrix(y_data_indices, probs_indices)
con_matrix = con_matrix / con_matrix.sum(axis=1, keepdims=True)
con_matrix = np.around(con_matrix, 2)
plt.figure(figsize=(30,30))
plt.title('Normalized Confusion Matrix')
sns.heatmap(con_matrix, annot=True, linewidths=.75, cmap="Blues")
# Out:
# <Axes: title={'center': 'Normalized Confusion Matrix'}>
